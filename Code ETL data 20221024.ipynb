# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
import mysql.connector

# %%
def retrieve_comments_data(Nrecords):
    CONNECTION_STRING = "mongodb+srv://longth:asdQWE123@cluster0.tehe2.azure.mongodb.net/?retryWrites=true&w=majority"
    print('Connection String is {}'.format(CONNECTION_STRING))
    client = MongoClient(CONNECTION_STRING)
    db = client['Data_Engineer']
    collection = db["Comments"]
    print('---------------')
    print('Getting data from Data_Engineer database , collection Comments')
    print('---------------')
    cursor = collection.find().limit(Nrecords)
    print('---------------')
    print('Retrieving data from MongoDB Comments')
    list_cur = list(cursor)
    pprint(list_cur[0:5])
    print('---------------')
    print('Processing noSQL data to Pandas DataFrame')
    print('---------------')
    comments_df = pd.DataFrame(list_cur)
    print(comments_df.head(5))
    return comments_df

# %% [markdown]
# <b> Đoạn này mình lấy 50 dòng từ MongoDB xuống thôi , bạn nào thích lấy full thì có thể ghi Nrecords = 885169 <b>

# %%
df = retrieve_comments_data(Nrecords = 10000)
# Out:
# Connection String is mongodb+srv://longth:asdQWE123@cluster0.tehe2.azure.mongodb.net/?retryWrites=true&w=majority
# ---------------
# Getting data from Data_Engineer database , collection Comments
# ---------------
# ---------------
# Retrieving data from MongoDB Comments
# [{'_id': ObjectId('555466761a77ce5d65ea062a'),
#   'comment_on': 'event',
#   'comment_status': 0,
#   'content': 'Chương trình \\ Tuyệt cú mèo\\ luôn, chờ lâu rồi mới có số mới, '
#              'hóng hóng',
#   'device': 'web-playfpt',
#   'device_id': 'null',
#   'dislike': 0,
#   'ip': 'null',
#   'layer': 0,
#   'like': 1,
#   'object_id': '552b2f0817dc135c89d7d6a2',
#   'publish_status': 1,
#   'ranking': 0,
#   'report_count': 0,
#   'report_reason': [],
#   'review_status': 1,
#   'reviewer': 'gianpt',
#   'timestamp': 1431595030,
#   'user_email': 'hoaianh2210@gmail.com',
#   'user_fullname': 'Nguyễn Hoài Anh',
#   'user_id': 12},
#  {'_id': ObjectId('555457bf1a77ce5d65ea0617'),
# ...

# %%
df.head()
# Out:
#                         _id  ranking  layer  user_id  like
# 0  555466761a77ce5d65ea062a        0      0       12     1  \
# 1  555457bf1a77ce5d65ea0617        0      0      130     5
# 2  555413001a77ce5d65ea0609        0      0   527201     0
# 3  555357f71a77ce5d65ea0606        0      0   424467     1
# 4  555491181a77ce5d65ea0636        0      0      805    12
#
#               user_email comment_on             ip      user_fullname
# 0  hoaianh2210@gmail.com      event           null    Nguyễn Hoài Anh  \
# 1    gian.phan@gmail.com      event           null    Phan Thanh Gian
# 2   cloudytang@gmail.com        vod   42.116.8.164       Đàm Ngọc Vân
# 3    n_x_cuong@yahoo.com        vod           null  nguyen xuan cuong
# 4    lequy1579@gmail.com        vod  42.117.66.148     Quang Quỳnh Lê
#
#    publish_status  ...                                            content
# 0               1  ...  Chương trình \ Tuyệt cú mèo\ luôn, chờ lâu rồi...  \
# ...

# %%
df.columns
# Out:
# Index(['_id', 'ranking', 'layer', 'user_id', 'like', 'user_email',
#        'comment_on', 'ip', 'user_fullname', 'publish_status', 'object_id',
#        'content', 'reviewer', 'report_count', 'review_status', 'timestamp',
#        'device', 'report_reason', 'dislike', 'comment_status', 'device_id'],
#       dtype='object')

# %% [markdown]
# <b> Chúng ta chỉ chọn ra các field cần thiết để import xuống SQL database , chứ không import hết <b>

# %% [markdown]
# ví dụ mình chỉ lấy các field : _id , content , comment_on và device

# %%
data = df[['_id','comment_on','content','device']]

# %%
data.head(5)
# Out:
#                         _id comment_on
# 0  555466761a77ce5d65ea062a      event  \
# 1  555457bf1a77ce5d65ea0617      event
# 2  555413001a77ce5d65ea0609        vod
# 3  555357f71a77ce5d65ea0606        vod
# 4  555491181a77ce5d65ea0636        vod
#
#                                              content       device
# 0  Chương trình \ Tuyệt cú mèo\ luôn, chờ lâu rồi...  web-playfpt
# 1  Chờ đợi chương trình này đã lâu! Hẹn mọi người...  web-playfpt
# 2                                        comment cai      android
# 3  lồng tiếng mà như tập đọc, nghe không nuốt nổi...  web-playfpt
# 4                                   Phim rất hay ;)      android

# %% [markdown]
# <b> Ngoài ra data cũng khá nặng 800k dòng , máy bạn nào yếu có thể lấy tầm 80k dòng để import thôi <b>

# %%
data = data[:10000]

# %%
data.columns
# Out:
# Index(['_id', 'comment_on', 'content', 'device'], dtype='object')

# %% [markdown]
# <b> Các bạn vào MySQL ở localhost ( nhớ bật localhost lên nếu dùng Wampserver ) , chọn database mình muốn import vào , và tạo 1 bảng trắng , có các cột như trong data.columns để hứng dữ liệu , và nhớ để ý data type phải match <B>

# %% [markdown]
# Như ở đây mình tạo 1 bảng tên là comments_data

# %%
def import_to_database(user,password,database,port,data):
    cnx = mysql.connector.connect(user=user,password=password,database =database , port = port )
    cursor = cnx.cursor()
    sql = """INSERT INTO comments_data (
        id,
        comment_on,
        content,
        device) VALUES (%s,%s,%s,%s)"""
    cursor.executemany(sql,data.values.tolist())
    cnx.commit()
    return print("Import Successfully")

# %%
import_to_database(user='root',password = '',database = 'homewwork', port = '3306',data=data)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 import_to_database(user='root',password = '',database = 'homewwork', port = '3306',data=data)
#
# Cell In[52], line 9, in import_to_database(user, password, database, port, data)
#       3 cursor = cnx.cursor()
#       4 sql = """INSERT INTO comments_data (
#       5     id,
#       6     comment_on,
#       7     content,
#       8     device) VALUES (%s,%s,%s,%s)"""
# ----> 9 cursor.executemany(sql,data.values.tolist())
#      10 cnx.commit()
#      11 return print("Import Successfully")
#
# File c:\Users\ACER\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:452, in CMySQLCursor.executemany(self, operation, seq_params)
#     450     self._rowcount = 0
#     451     return None
# --> 452 stmt = self._batch_insert(operation, seq_params)
# ...

# %% [markdown]
# Làm đến đây là đã import data vào SQL xong , mọi người vào bảng comments_data để check dữ liệu
